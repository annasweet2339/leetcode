# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def checkIfPangram(self, sentence: str) -> bool:
        com = set(chr(a_z) for a_z in range(ord('a'),ord('z')+1))#Time complexity is 26
        return set(sentence) == com # 看sentence裡面的一個有沒有在com 依序這樣看 所以Time complexity會是O(len(sentence))
